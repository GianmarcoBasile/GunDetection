# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import xml.etree.ElementTree as ET
import os

HOME = os.path.abspath(os.sep)
dataset_folder = os.getcwd() + "/Dataset/Images"

# %%
import os
import json
import torch
from PIL import Image
from torch.utils.data import Dataset

class GunDataset(Dataset):
    def __init__(self, root_dir, annotations_file, transforms=None):
        """
        Args:
            root_dir (str): Directory contenente le immagini.
            annotations_file (str): Percorso al file _annotations.coco.json.
            transform (callable, optional): Trasformazioni da applicare alle immagini.
        """
        # Carica annotazioni COCO
        with open(annotations_file, 'r') as f:
            coco_data = json.load(f)
            
        self.root_dir = root_dir
        self.transforms = transforms
        self.images = coco_data['images']
        self.annotations = coco_data['annotations']
        self.classes = ['gun']

        # Organizza annotazioni per immagine
        self.img_to_anns = {img['id']: [] for img in self.images}
        for ann in self.annotations:
            self.img_to_anns[ann['image_id']].append(ann)

    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        # Recupera l'immagine
        img_info = self.images[idx]
        img_id = img_info['id']
        img_path = f"{self.root_dir}/{img_info['file_name']}"
        image = Image.open(img_path).convert("RGB")

        # Recupera le annotazioni per questa immagine
        annotations = self.img_to_anns[img_id]
        boxes = []
        labels = []
        iscrowd = []
        areas = []  # Lista per memorizzare l'area di ogni bounding box

        for ann in annotations:
            # Estrai il bounding box (x_min, y_min, width, height)
            bbox = ann['bbox']
            x_min, y_min, width, height = bbox
            x_max = x_min + width
            y_max = y_min + height
            boxes.append([x_min, y_min, x_max, y_max])

            # Calcola l'area del bounding box
            area = width * height
            areas.append(area)

            # Aggiungi l'etichetta della categoria (ad esempio "pistola")
            label = ann['category_id']
            labels.append(label)

            # Indica se l'oggetto è occluso
            iscrowd.append(ann.get('iscrowd', 0))

        # Converti le liste in tensori
        boxes = torch.tensor(boxes, dtype=torch.float32)
        labels = torch.tensor(labels, dtype=torch.int64)
        iscrowd = torch.tensor(iscrowd, dtype=torch.int64)
        areas = torch.tensor(areas, dtype=torch.float32)  # Converti in tensor

        # Crea il dizionario delle annotazioni
        target = {
            'image_id': img_id,
            'boxes': boxes,
            'labels': labels,
            'iscrowd': iscrowd,
            'area': areas  # Aggiungi l'area nel dizionario
        }

        # Applica le trasformazioni se presenti
        if self.transforms:
            image = self.transforms(image)

        return image, target

# %%
import torchvision.transforms as T
from torch.utils.data import DataLoader, random_split

transforms = T.Compose([T.ToTensor()])

# load dataset
dataset = GunDataset(dataset_folder, dataset_folder + "/_annotations.coco.json", transforms=transforms)

# define splits
train_size = int(0.8*len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

num_workers = 2
#num_workers
if os.name == 'nt':
    num_workers = 0

# data loaders
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=num_workers, collate_fn=lambda x: tuple(zip(*x)), pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, num_workers=num_workers, collate_fn=lambda x: tuple(zip(*x)))

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FasterRCNN_ResNet50_FPN_Weights
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
num_classes = 2
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 3, gamma = 0.1)

# %%
from engine import train_one_epoch, evaluate
num_epochs = 5
for epoch in range(5):
    train_loss = train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)
    lr_scheduler.step()
    val_loss = evaluate(model, val_loader, device)
# Out:
# Epoch: [0]  [  0/297]  eta: 1:26:55  lr: 0.000044  loss: 0.9299 (0.9299)  loss_classifier: 0.7082 (0.7082)  loss_box_reg: 0.2043 (0.2043)  loss_objectness: 0.0084 (0.0084)  loss_rpn_box_reg: 0.0090 (0.0090)  time: 17.5619  data: 0.1832  max mem: 7187
# Epoch: [0]  [ 10/297]  eta: 1:23:12  lr: 0.000381  loss: 0.7511 (0.6753)  loss_classifier: 0.5486 (0.5045)  loss_box_reg: 0.1311 (0.1481)  loss_objectness: 0.0135 (0.0124)  loss_rpn_box_reg: 0.0094 (0.0103)  time: 17.3939  data: 0.0749  max mem: 7344
# Epoch: [0]  [ 20/297]  eta: 1:21:50  lr: 0.000719  loss: 0.3921 (0.5109)  loss_classifier: 0.2033 (0.3423)  loss_box_reg: 0.1296 (0.1433)  loss_objectness: 0.0135 (0.0153)  loss_rpn_box_reg: 0.0092 (0.0100)  time: 17.7342  data: 0.0640  max mem: 7344
# Epoch: [0]  [ 30/297]  eta: 3:26:41  lr: 0.001056  loss: 0.2854 (0.4429)  loss_classifier: 0.1520 (0.2816)  loss_box_reg: 0.1155 (0.1362)  loss_objectness: 0.0135 (0.0154)  loss_rpn_box_reg: 0.0088 (0.0097)  time: 62.4291  data: 0.0680  max mem: 7344
# Epoch: [0]  [ 40/297]  eta: 3:11:20  lr: 0.001394  loss: 0.2653 (0.3996)  loss_classifier: 0.1225 (0.2395)  loss_box_reg: 0.1137 (0.1339)  loss_objectness: 0.0146 (0.0167)  loss_rpn_box_reg: 0.0084 (0.0094)  time: 72.9607  data: 0.0673  max mem: 7344
# Epoch: [0]  [ 50/297]  eta: 2:59:46  lr: 0.001731  loss: 0.2309 (0.3634)  loss_classifier: 0.0843 (0.2075)  loss_box_reg: 0.1120 (0.1305)  loss_objectness: 0.0146 (0.0159)  loss_rpn_box_reg: 0.0093 (0.0095)  time: 39.3636  data: 0.0629  max mem: 7344
# Epoch: [0]  [ 60/297]  eta: 2:47:19  lr: 0.002069  loss: 0.2058 (0.3402)  loss_classifier: 0.0698 (0.1852)  loss_box_reg: 0.1214 (0.1309)  loss_objectness: 0.0092 (0.0152)  loss_rpn_box_reg: 0.0071 (0.0089)  time: 37.6264  data: 0.0634  max mem: 7344
# Epoch: [0]  [ 70/297]  eta: 2:34:38  lr: 0.002406  loss: 0.2021 (0.3214)  loss_classifier: 0.0596 (0.1674)  loss_box_reg: 0.1240 (0.1306)  loss_objectness: 0.0075 (0.0146)  loss_rpn_box_reg: 0.0064 (0.0087)  time: 33.7524  data: 0.0636  max mem: 7344
# Epoch: [0]  [ 80/297]  eta: 3:02:43  lr: 0.002744  loss: 0.1862 (0.3031)  loss_classifier: 0.0526 (0.1534)  loss_box_reg: 0.1130 (0.1278)  loss_objectness: 0.0047 (0.0135)  loss_rpn_box_reg: 0.0064 (0.0084)  time: 75.4116  data: 0.0644  max mem: 7344
# Epoch: [0]  [ 90/297]  eta: 3:09:32  lr: 0.003081  loss: 0.1874 (0.2924)  loss_classifier: 0.0543 (0.1437)  loss_box_reg: 0.1106 (0.1269)  loss_objectness: 0.0062 (0.0136)  loss_rpn_box_reg: 0.0062 (0.0082)  time: 104.8705  data: 0.0639  max mem: 7344
# Epoch: [0]  [100/297]  eta: 2:54:27  lr: 0.003419  loss: 0.1809 (0.2830)  loss_classifier: 0.0593 (0.1361)  loss_box_reg: 0.1002 (0.1249)  loss_objectness: 0.0109 (0.0139)  loss_rpn_box_reg: 0.0059 (0.0082)  time: 63.7188  data: 0.0633  max mem: 7344
# Epoch: [0]  [110/297]  eta: 2:41:03  lr: 0.003756  loss: 0.1389 (0.2692)  loss_classifier: 0.0492 (0.1279)  loss_box_reg: 0.0794 (0.1202)  loss_objectness: 0.0066 (0.0132)  loss_rpn_box_reg: 0.0050 (0.0080)  time: 36.8313  data: 0.0627  max mem: 7344
# Epoch: [0]  [120/297]  eta: 2:28:47  lr: 0.004094  loss: 0.1356 (0.2596)  loss_classifier: 0.0478 (0.1218)  loss_box_reg: 0.0777 (0.1174)  loss_objectness: 0.0047 (0.0126)  loss_rpn_box_reg: 0.0054 (0.0078)  time: 36.8364  data: 0.0636  max mem: 7344
# Epoch: [0]  [130/297]  eta: 2:17:48  lr: 0.004431  loss: 0.1338 (0.2494)  loss_classifier: 0.0478 (0.1158)  loss_box_reg: 0.0777 (0.1139)  loss_objectness: 0.0040 (0.0121)  loss_rpn_box_reg: 0.0056 (0.0077)  time: 37.4797  data: 0.0637  max mem: 7344
# Epoch: [0]  [140/297]  eta: 2:06:36  lr: 0.004769  loss: 0.1252 (0.2413)  loss_classifier: 0.0425 (0.1110)  loss_box_reg: 0.0664 (0.1108)  loss_objectness: 0.0050 (0.0120)  loss_rpn_box_reg: 0.0056 (0.0075)  time: 35.9397  data: 0.0618  max mem: 7344
# Epoch: [0]  [150/297]  eta: 1:56:42  lr: 0.005106  loss: 0.1337 (0.2350)  loss_classifier: 0.0483 (0.1070)  loss_box_reg: 0.0709 (0.1089)  loss_objectness: 0.0066 (0.0117)  loss_rpn_box_reg: 0.0050 (0.0073)  time: 35.3364  data: 0.0634  max mem: 7344
# Epoch: [0]  [160/297]  eta: 1:47:14  lr: 0.005444  loss: 0.1271 (0.2281)  loss_classifier: 0.0423 (0.1030)  loss_box_reg: 0.0764 (0.1066)  loss_objectness: 0.0063 (0.0113)  loss_rpn_box_reg: 0.0047 (0.0072)  time: 36.9605  data: 0.0654  max mem: 7344
# Epoch: [0]  [170/297]  eta: 1:37:35  lr: 0.005781  loss: 0.1344 (0.2237)  loss_classifier: 0.0458 (0.1003)  loss_box_reg: 0.0784 (0.1052)  loss_objectness: 0.0060 (0.0112)  loss_rpn_box_reg: 0.0055 (0.0071)  time: 34.5569  data: 0.0669  max mem: 7344
# Epoch: [0]  [180/297]  eta: 1:28:21  lr: 0.006119  loss: 0.1382 (0.2186)  loss_classifier: 0.0537 (0.0974)  loss_box_reg: 0.0732 (0.1032)  loss_objectness: 0.0063 (0.0111)  loss_rpn_box_reg: 0.0053 (0.0070)  time: 32.0121  data: 0.0667  max mem: 7344
# Epoch: [0]  [190/297]  eta: 1:19:35  lr: 0.006456  loss: 0.1259 (0.2140)  loss_classifier: 0.0503 (0.0949)  loss_box_reg: 0.0685 (0.1015)  loss_objectness: 0.0044 (0.0108)  loss_rpn_box_reg: 0.0045 (0.0069)  time: 32.0199  data: 0.0642  max mem: 7344
# Epoch: [0]  [200/297]  eta: 1:11:13  lr: 0.006794  loss: 0.1259 (0.2096)  loss_classifier: 0.0503 (0.0924)  loss_box_reg: 0.0685 (0.0996)  loss_objectness: 0.0044 (0.0107)  loss_rpn_box_reg: 0.0045 (0.0068)  time: 32.6831  data: 0.0637  max mem: 7344
# Epoch: [0]  [210/297]  eta: 1:03:33  lr: 0.007131  loss: 0.1107 (0.2045)  loss_classifier: 0.0352 (0.0898)  loss_box_reg: 0.0556 (0.0977)  loss_objectness: 0.0048 (0.0104)  loss_rpn_box_reg: 0.0039 (0.0067)  time: 36.2781  data: 0.0639  max mem: 7344
# Epoch: [0]  [220/297]  eta: 0:55:55  lr: 0.007469  loss: 0.1107 (0.2004)  loss_classifier: 0.0357 (0.0876)  loss_box_reg: 0.0620 (0.0961)  loss_objectness: 0.0042 (0.0102)  loss_rpn_box_reg: 0.0039 (0.0066)  time: 38.8204  data: 0.0651  max mem: 7344
# Epoch: [0]  [230/297]  eta: 0:48:04  lr: 0.007806  loss: 0.1217 (0.1983)  loss_classifier: 0.0429 (0.0863)  loss_box_reg: 0.0620 (0.0952)  loss_objectness: 0.0068 (0.0102)  loss_rpn_box_reg: 0.0043 (0.0065)  time: 34.7888  data: 0.0649  max mem: 7344
# Epoch: [0]  [240/297]  eta: 0:40:27  lr: 0.008144  loss: 0.1251 (0.1950)  loss_classifier: 0.0549 (0.0847)  loss_box_reg: 0.0616 (0.0938)  loss_objectness: 0.0073 (0.0100)  loss_rpn_box_reg: 0.0043 (0.0064)  time: 31.5798  data: 0.0625  max mem: 7344
# Epoch: [0]  [250/297]  eta: 0:33:03  lr: 0.008481  loss: 0.1161 (0.1915)  loss_classifier: 0.0410 (0.0828)  loss_box_reg: 0.0616 (0.0925)  loss_objectness: 0.0056 (0.0098)  loss_rpn_box_reg: 0.0041 (0.0063)  time: 32.3722  data: 0.0624  max mem: 7344
# Epoch: [0]  [260/297]  eta: 0:25:48  lr: 0.008819  loss: 0.1074 (0.1892)  loss_classifier: 0.0396 (0.0814)  loss_box_reg: 0.0598 (0.0918)  loss_objectness: 0.0049 (0.0096)  loss_rpn_box_reg: 0.0042 (0.0063)  time: 32.8331  data: 0.0633  max mem: 7344
# Epoch: [0]  [270/297]  eta: 0:18:44  lr: 0.009156  loss: 0.1122 (0.1869)  loss_classifier: 0.0436 (0.0802)  loss_box_reg: 0.0604 (0.0910)  loss_objectness: 0.0046 (0.0094)  loss_rpn_box_reg: 0.0045 (0.0062)  time: 34.6589  data: 0.0621  max mem: 7344
# Epoch: [0]  [280/297]  eta: 0:11:45  lr: 0.009494  loss: 0.1122 (0.1847)  loss_classifier: 0.0446 (0.0791)  loss_box_reg: 0.0628 (0.0901)  loss_objectness: 0.0046 (0.0093)  loss_rpn_box_reg: 0.0044 (0.0062)  time: 36.8737  data: 0.0627  max mem: 7344
# Epoch: [0]  [290/297]  eta: 0:04:48  lr: 0.009831  loss: 0.1103 (0.1825)  loss_classifier: 0.0413 (0.0779)  loss_box_reg: 0.0587 (0.0891)  loss_objectness: 0.0056 (0.0093)  loss_rpn_box_reg: 0.0048 (0.0062)  time: 34.3314  data: 0.0629  max mem: 7344
# Epoch: [0]  [296/297]  eta: 0:00:40  lr: 0.010000  loss: 0.1113 (0.1810)  loss_classifier: 0.0410 (0.0771)  loss_box_reg: 0.0587 (0.0885)  loss_objectness: 0.0056 (0.0093)  loss_rpn_box_reg: 0.0044 (0.0061)  time: 32.8631  data: 0.0606  max mem: 7344
# Epoch: [0] Total time: 3:22:43 (40.9536 s / it)
# creating index...
# index created!
# Test:  [ 0/75]  eta: 0:19:39  model_time: 15.6829 (15.6829)  evaluator_time: 0.0166 (0.0166)  time: 15.7289  data: 0.0125  max mem: 7344
# Test:  [74/75]  eta: 0:00:17  model_time: 19.4330 (17.4288)  evaluator_time: 0.0000 (0.0037)  time: 18.5140  data: 0.0177  max mem: 7344
# Test: Total time: 0:21:49 (17.4565 s / it)
# Averaged stats: model_time: 19.4330 (17.4288)  evaluator_time: 0.0000 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.663
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.641
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
# Epoch: [1]  [  0/297]  eta: 3:01:45  lr: 0.010000  loss: 0.1526 (0.1526)  loss_classifier: 0.0487 (0.0487)  loss_box_reg: 0.0944 (0.0944)  loss_objectness: 0.0058 (0.0058)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 36.7200  data: 0.0169  max mem: 7344
# Epoch: [1]  [ 10/297]  eta: 2:43:59  lr: 0.010000  loss: 0.1008 (0.0962)  loss_classifier: 0.0285 (0.0305)  loss_box_reg: 0.0567 (0.0580)  loss_objectness: 0.0024 (0.0035)  loss_rpn_box_reg: 0.0043 (0.0042)  time: 34.2846  data: 0.0113  max mem: 7344
# Epoch: [1]  [ 20/297]  eta: 2:33:07  lr: 0.010000  loss: 0.0804 (0.0936)  loss_classifier: 0.0273 (0.0308)  loss_box_reg: 0.0514 (0.0555)  loss_objectness: 0.0018 (0.0029)  loss_rpn_box_reg: 0.0043 (0.0044)  time: 32.9893  data: 0.0108  max mem: 7344
# Epoch: [1]  [ 30/297]  eta: 2:24:35  lr: 0.010000  loss: 0.0904 (0.1043)  loss_classifier: 0.0280 (0.0354)  loss_box_reg: 0.0516 (0.0596)  loss_objectness: 0.0026 (0.0041)  loss_rpn_box_reg: 0.0050 (0.0052)  time: 31.5086  data: 0.0097  max mem: 7344
# Epoch: [1]  [ 40/297]  eta: 2:30:27  lr: 0.010000  loss: 0.1012 (0.1040)  loss_classifier: 0.0322 (0.0352)  loss_box_reg: 0.0585 (0.0598)  loss_objectness: 0.0029 (0.0039)  loss_rpn_box_reg: 0.0054 (0.0051)  time: 37.1845  data: 0.0126  max mem: 7344
# Epoch: [1]  [ 50/297]  eta: 2:10:47  lr: 0.010000  loss: 0.1105 (0.1078)  loss_classifier: 0.0377 (0.0369)  loss_box_reg: 0.0585 (0.0615)  loss_objectness: 0.0027 (0.0043)  loss_rpn_box_reg: 0.0042 (0.0050)  time: 30.6518  data: 0.0177  max mem: 7344
# Epoch: [1]  [ 60/297]  eta: 1:56:05  lr: 0.010000  loss: 0.1141 (0.1092)  loss_classifier: 0.0406 (0.0374)  loss_box_reg: 0.0662 (0.0626)  loss_objectness: 0.0031 (0.0045)  loss_rpn_box_reg: 0.0035 (0.0047)  time: 17.6297  data: 0.0191  max mem: 7344
# Epoch: [1]  [ 70/297]  eta: 1:44:50  lr: 0.010000  loss: 0.1028 (0.1059)  loss_classifier: 0.0336 (0.0360)  loss_box_reg: 0.0610 (0.0609)  loss_objectness: 0.0027 (0.0044)  loss_rpn_box_reg: 0.0032 (0.0046)  time: 17.3588  data: 0.0188  max mem: 7344
# Epoch: [1]  [ 80/297]  eta: 1:45:49  lr: 0.010000  loss: 0.0924 (0.1067)  loss_classifier: 0.0336 (0.0365)  loss_box_reg: 0.0534 (0.0616)  loss_objectness: 0.0020 (0.0041)  loss_rpn_box_reg: 0.0034 (0.0045)  time: 28.8624  data: 0.0198  max mem: 7344
# Epoch: [1]  [ 90/297]  eta: 1:41:39  lr: 0.010000  loss: 0.0939 (0.1053)  loss_classifier: 0.0327 (0.0361)  loss_box_reg: 0.0542 (0.0609)  loss_objectness: 0.0018 (0.0039)  loss_rpn_box_reg: 0.0035 (0.0044)  time: 35.6861  data: 0.0223  max mem: 7344
# Epoch: [1]  [100/297]  eta: 1:38:18  lr: 0.010000  loss: 0.0985 (0.1059)  loss_classifier: 0.0317 (0.0361)  loss_box_reg: 0.0617 (0.0616)  loss_objectness: 0.0022 (0.0038)  loss_rpn_box_reg: 0.0035 (0.0044)  time: 32.7116  data: 0.0234  max mem: 7344
# Epoch: [1]  [110/297]  eta: 1:33:56  lr: 0.010000  loss: 0.0970 (0.1050)  loss_classifier: 0.0324 (0.0358)  loss_box_reg: 0.0589 (0.0613)  loss_objectness: 0.0019 (0.0036)  loss_rpn_box_reg: 0.0035 (0.0043)  time: 33.2181  data: 0.0240  max mem: 7344
# Epoch: [1]  [120/297]  eta: 1:29:27  lr: 0.010000  loss: 0.0954 (0.1054)  loss_classifier: 0.0335 (0.0360)  loss_box_reg: 0.0545 (0.0615)  loss_objectness: 0.0019 (0.0037)  loss_rpn_box_reg: 0.0037 (0.0043)  time: 32.2598  data: 0.0240  max mem: 7344
# Epoch: [1]  [130/297]  eta: 1:24:26  lr: 0.010000  loss: 0.1018 (0.1046)  loss_classifier: 0.0350 (0.0358)  loss_box_reg: 0.0544 (0.0610)  loss_objectness: 0.0027 (0.0036)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 31.4385  data: 0.0238  max mem: 7344
# Epoch: [1]  [140/297]  eta: 1:19:12  lr: 0.010000  loss: 0.0912 (0.1045)  loss_classifier: 0.0350 (0.0359)  loss_box_reg: 0.0522 (0.0607)  loss_objectness: 0.0024 (0.0037)  loss_rpn_box_reg: 0.0036 (0.0042)  time: 29.9190  data: 0.0235  max mem: 7344
# Epoch: [1]  [150/297]  eta: 1:12:10  lr: 0.010000  loss: 0.0904 (0.1039)  loss_classifier: 0.0304 (0.0356)  loss_box_reg: 0.0522 (0.0604)  loss_objectness: 0.0028 (0.0036)  loss_rpn_box_reg: 0.0034 (0.0042)  time: 23.7105  data: 0.0223  max mem: 7344
# Epoch: [1]  [160/297]  eta: 1:05:38  lr: 0.010000  loss: 0.0876 (0.1044)  loss_classifier: 0.0342 (0.0361)  loss_box_reg: 0.0517 (0.0605)  loss_objectness: 0.0031 (0.0037)  loss_rpn_box_reg: 0.0032 (0.0042)  time: 18.0362  data: 0.0207  max mem: 7344
# Epoch: [1]  [170/297]  eta: 0:59:31  lr: 0.010000  loss: 0.0965 (0.1037)  loss_classifier: 0.0338 (0.0361)  loss_box_reg: 0.0509 (0.0599)  loss_objectness: 0.0022 (0.0036)  loss_rpn_box_reg: 0.0033 (0.0041)  time: 17.9976  data: 0.0202  max mem: 7344
# Epoch: [1]  [180/297]  eta: 0:53:54  lr: 0.010000  loss: 0.0971 (0.1045)  loss_classifier: 0.0330 (0.0363)  loss_box_reg: 0.0523 (0.0602)  loss_objectness: 0.0022 (0.0038)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 18.7264  data: 0.0202  max mem: 7344
# Epoch: [1]  [190/297]  eta: 0:48:30  lr: 0.010000  loss: 0.1039 (0.1052)  loss_classifier: 0.0351 (0.0364)  loss_box_reg: 0.0596 (0.0608)  loss_objectness: 0.0026 (0.0037)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 19.3463  data: 0.0207  max mem: 7344
# Epoch: [1]  [200/297]  eta: 0:43:20  lr: 0.010000  loss: 0.0855 (0.1040)  loss_classifier: 0.0289 (0.0360)  loss_box_reg: 0.0532 (0.0601)  loss_objectness: 0.0025 (0.0037)  loss_rpn_box_reg: 0.0035 (0.0042)  time: 19.3187  data: 0.0209  max mem: 7344
# Epoch: [1]  [210/297]  eta: 0:38:20  lr: 0.010000  loss: 0.0842 (0.1041)  loss_classifier: 0.0320 (0.0362)  loss_box_reg: 0.0418 (0.0599)  loss_objectness: 0.0039 (0.0038)  loss_rpn_box_reg: 0.0034 (0.0042)  time: 19.2389  data: 0.0223  max mem: 7344
# Epoch: [1]  [220/297]  eta: 0:33:28  lr: 0.010000  loss: 0.0835 (0.1033)  loss_classifier: 0.0320 (0.0360)  loss_box_reg: 0.0432 (0.0594)  loss_objectness: 0.0039 (0.0037)  loss_rpn_box_reg: 0.0035 (0.0042)  time: 18.6996  data: 0.0220  max mem: 7344
# Epoch: [1]  [230/297]  eta: 0:28:45  lr: 0.010000  loss: 0.0835 (0.1033)  loss_classifier: 0.0321 (0.0360)  loss_box_reg: 0.0461 (0.0593)  loss_objectness: 0.0026 (0.0038)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 18.4247  data: 0.0202  max mem: 7344
# Epoch: [1]  [240/297]  eta: 0:24:12  lr: 0.010000  loss: 0.0797 (0.1023)  loss_classifier: 0.0298 (0.0356)  loss_box_reg: 0.0454 (0.0588)  loss_objectness: 0.0026 (0.0038)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 18.8798  data: 0.0205  max mem: 7344
# Epoch: [1]  [250/297]  eta: 0:19:47  lr: 0.010000  loss: 0.0846 (0.1023)  loss_classifier: 0.0272 (0.0357)  loss_box_reg: 0.0512 (0.0586)  loss_objectness: 0.0026 (0.0038)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 19.5644  data: 0.0211  max mem: 7344
# Epoch: [1]  [260/297]  eta: 0:15:32  lr: 0.010000  loss: 0.1033 (0.1024)  loss_classifier: 0.0365 (0.0358)  loss_box_reg: 0.0615 (0.0586)  loss_objectness: 0.0034 (0.0039)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 21.9897  data: 0.0219  max mem: 7344
# Epoch: [1]  [270/297]  eta: 0:11:21  lr: 0.010000  loss: 0.1009 (0.1027)  loss_classifier: 0.0385 (0.0361)  loss_box_reg: 0.0547 (0.0586)  loss_objectness: 0.0034 (0.0039)  loss_rpn_box_reg: 0.0038 (0.0042)  time: 25.1056  data: 0.0210  max mem: 7344
# Epoch: [1]  [280/297]  eta: 0:07:09  lr: 0.010000  loss: 0.0952 (0.1028)  loss_classifier: 0.0369 (0.0361)  loss_box_reg: 0.0522 (0.0586)  loss_objectness: 0.0029 (0.0039)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 25.5213  data: 0.0202  max mem: 7344
# Epoch: [1]  [290/297]  eta: 0:02:56  lr: 0.010000  loss: 0.0869 (0.1028)  loss_classifier: 0.0321 (0.0362)  loss_box_reg: 0.0512 (0.0586)  loss_objectness: 0.0027 (0.0038)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 25.1689  data: 0.0204  max mem: 7344
# Epoch: [1]  [296/297]  eta: 0:00:25  lr: 0.010000  loss: 0.0782 (0.1022)  loss_classifier: 0.0283 (0.0360)  loss_box_reg: 0.0476 (0.0583)  loss_objectness: 0.0024 (0.0038)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 24.8598  data: 0.0205  max mem: 7344
# Epoch: [1] Total time: 2:04:53 (25.2312 s / it)
# creating index...
# index created!
# Test:  [ 0/75]  eta: 0:03:18  model_time: 2.6086 (2.6086)  evaluator_time: 0.0050 (0.0050)  time: 2.6465  data: 0.0179  max mem: 7344
# Test:  [74/75]  eta: 0:00:02  model_time: 2.4742 (2.4525)  evaluator_time: 0.0036 (0.0037)  time: 2.3898  data: 0.0175  max mem: 7344
# Test: Total time: 0:03:05 (2.4775 s / it)
# Averaged stats: model_time: 2.4742 (2.4525)  evaluator_time: 0.0036 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.594
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.874
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.673
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.661
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.436
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.758
# Epoch: [2]  [  0/297]  eta: 2:00:13  lr: 0.010000  loss: 0.2153 (0.2153)  loss_classifier: 0.0624 (0.0624)  loss_box_reg: 0.1418 (0.1418)  loss_objectness: 0.0056 (0.0056)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 24.2892  data: 0.0180  max mem: 7344
# Epoch: [2]  [ 10/297]  eta: 1:49:50  lr: 0.010000  loss: 0.0821 (0.1080)  loss_classifier: 0.0302 (0.0377)  loss_box_reg: 0.0472 (0.0636)  loss_objectness: 0.0019 (0.0029)  loss_rpn_box_reg: 0.0035 (0.0038)  time: 22.9630  data: 0.0168  max mem: 7344
# Epoch: [2]  [ 20/297]  eta: 1:49:23  lr: 0.010000  loss: 0.0675 (0.0892)  loss_classifier: 0.0243 (0.0309)  loss_box_reg: 0.0411 (0.0524)  loss_objectness: 0.0017 (0.0023)  loss_rpn_box_reg: 0.0031 (0.0036)  time: 23.6643  data: 0.0169  max mem: 7344
# Epoch: [2]  [ 30/297]  eta: 1:47:13  lr: 0.010000  loss: 0.0696 (0.0894)  loss_classifier: 0.0243 (0.0306)  loss_box_reg: 0.0423 (0.0531)  loss_objectness: 0.0016 (0.0022)  loss_rpn_box_reg: 0.0032 (0.0035)  time: 24.7207  data: 0.0187  max mem: 7344
# Epoch: [2]  [ 40/297]  eta: 1:42:49  lr: 0.010000  loss: 0.0708 (0.0853)  loss_classifier: 0.0239 (0.0288)  loss_box_reg: 0.0436 (0.0510)  loss_objectness: 0.0016 (0.0021)  loss_rpn_box_reg: 0.0034 (0.0035)  time: 24.3355  data: 0.0182  max mem: 7344
# Epoch: [2]  [ 50/297]  eta: 1:39:52  lr: 0.010000  loss: 0.0605 (0.0828)  loss_classifier: 0.0217 (0.0279)  loss_box_reg: 0.0355 (0.0494)  loss_objectness: 0.0016 (0.0021)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 24.5135  data: 0.0162  max mem: 7344
# Epoch: [2]  [ 60/297]  eta: 1:37:46  lr: 0.010000  loss: 0.0723 (0.0849)  loss_classifier: 0.0244 (0.0284)  loss_box_reg: 0.0433 (0.0506)  loss_objectness: 0.0019 (0.0023)  loss_rpn_box_reg: 0.0030 (0.0035)  time: 26.2862  data: 0.0172  max mem: 7344
# Epoch: [2]  [ 70/297]  eta: 1:34:37  lr: 0.010000  loss: 0.0760 (0.0839)  loss_classifier: 0.0244 (0.0280)  loss_box_reg: 0.0479 (0.0502)  loss_objectness: 0.0016 (0.0022)  loss_rpn_box_reg: 0.0030 (0.0034)  time: 26.9282  data: 0.0176  max mem: 7344
# Epoch: [2]  [ 80/297]  eta: 1:31:12  lr: 0.010000  loss: 0.0637 (0.0816)  loss_classifier: 0.0230 (0.0273)  loss_box_reg: 0.0396 (0.0488)  loss_objectness: 0.0012 (0.0022)  loss_rpn_box_reg: 0.0025 (0.0033)  time: 26.6452  data: 0.0166  max mem: 7344
# Epoch: [2]  [ 90/297]  eta: 1:27:14  lr: 0.010000  loss: 0.0614 (0.0815)  loss_classifier: 0.0230 (0.0272)  loss_box_reg: 0.0401 (0.0489)  loss_objectness: 0.0013 (0.0021)  loss_rpn_box_reg: 0.0025 (0.0033)  time: 26.2692  data: 0.0168  max mem: 7344
# Epoch: [2]  [100/297]  eta: 1:23:42  lr: 0.010000  loss: 0.0687 (0.0808)  loss_classifier: 0.0217 (0.0270)  loss_box_reg: 0.0418 (0.0484)  loss_objectness: 0.0012 (0.0021)  loss_rpn_box_reg: 0.0030 (0.0033)  time: 26.5936  data: 0.0166  max mem: 7344
# Epoch: [2]  [110/297]  eta: 1:19:50  lr: 0.010000  loss: 0.0687 (0.0807)  loss_classifier: 0.0213 (0.0270)  loss_box_reg: 0.0410 (0.0483)  loss_objectness: 0.0012 (0.0021)  loss_rpn_box_reg: 0.0030 (0.0033)  time: 27.1232  data: 0.0159  max mem: 7344
# Epoch: [2]  [120/297]  eta: 1:15:51  lr: 0.010000  loss: 0.0768 (0.0810)  loss_classifier: 0.0241 (0.0272)  loss_box_reg: 0.0448 (0.0484)  loss_objectness: 0.0019 (0.0021)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 26.8255  data: 0.0153  max mem: 7344
# Epoch: [2]  [130/297]  eta: 1:11:32  lr: 0.010000  loss: 0.0768 (0.0811)  loss_classifier: 0.0263 (0.0273)  loss_box_reg: 0.0457 (0.0484)  loss_objectness: 0.0018 (0.0021)  loss_rpn_box_reg: 0.0029 (0.0033)  time: 26.1680  data: 0.0160  max mem: 7344
# Epoch: [2]  [140/297]  eta: 1:07:19  lr: 0.010000  loss: 0.0713 (0.0804)  loss_classifier: 0.0221 (0.0270)  loss_box_reg: 0.0388 (0.0480)  loss_objectness: 0.0011 (0.0021)  loss_rpn_box_reg: 0.0029 (0.0033)  time: 25.8070  data: 0.0160  max mem: 7344
# Epoch: [2]  [150/297]  eta: 1:02:52  lr: 0.010000  loss: 0.0617 (0.0790)  loss_classifier: 0.0176 (0.0265)  loss_box_reg: 0.0365 (0.0472)  loss_objectness: 0.0011 (0.0021)  loss_rpn_box_reg: 0.0032 (0.0033)  time: 25.4076  data: 0.0161  max mem: 7344
# Epoch: [2]  [160/297]  eta: 0:58:18  lr: 0.010000  loss: 0.0688 (0.0792)  loss_classifier: 0.0209 (0.0265)  loss_box_reg: 0.0411 (0.0473)  loss_objectness: 0.0013 (0.0021)  loss_rpn_box_reg: 0.0030 (0.0033)  time: 24.2230  data: 0.0195  max mem: 7344
# Epoch: [2]  [170/297]  eta: 0:53:51  lr: 0.010000  loss: 0.0713 (0.0791)  loss_classifier: 0.0233 (0.0265)  loss_box_reg: 0.0427 (0.0473)  loss_objectness: 0.0011 (0.0020)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 23.7712  data: 0.0199  max mem: 7344
# Epoch: [2]  [180/297]  eta: 0:49:29  lr: 0.010000  loss: 0.0754 (0.0799)  loss_classifier: 0.0268 (0.0268)  loss_box_reg: 0.0427 (0.0477)  loss_objectness: 0.0011 (0.0021)  loss_rpn_box_reg: 0.0029 (0.0033)  time: 24.0663  data: 0.0197  max mem: 7344
# Epoch: [2]  [190/297]  eta: 0:45:04  lr: 0.010000  loss: 0.0670 (0.0793)  loss_classifier: 0.0259 (0.0266)  loss_box_reg: 0.0405 (0.0473)  loss_objectness: 0.0013 (0.0020)  loss_rpn_box_reg: 0.0031 (0.0033)  time: 23.8899  data: 0.0193  max mem: 7344
# Epoch: [2]  [200/297]  eta: 0:40:46  lr: 0.010000  loss: 0.0665 (0.0790)  loss_classifier: 0.0234 (0.0265)  loss_box_reg: 0.0405 (0.0471)  loss_objectness: 0.0013 (0.0020)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 23.8556  data: 0.0195  max mem: 7344
# Epoch: [2]  [210/297]  eta: 0:36:26  lr: 0.010000  loss: 0.0755 (0.0793)  loss_classifier: 0.0250 (0.0267)  loss_box_reg: 0.0432 (0.0472)  loss_objectness: 0.0020 (0.0021)  loss_rpn_box_reg: 0.0029 (0.0033)  time: 23.7319  data: 0.0210  max mem: 7344
# Epoch: [2]  [220/297]  eta: 0:32:10  lr: 0.010000  loss: 0.0755 (0.0796)  loss_classifier: 0.0250 (0.0268)  loss_box_reg: 0.0470 (0.0473)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 23.4775  data: 0.0196  max mem: 7344
# Epoch: [2]  [230/297]  eta: 0:27:53  lr: 0.010000  loss: 0.0660 (0.0793)  loss_classifier: 0.0203 (0.0267)  loss_box_reg: 0.0403 (0.0471)  loss_objectness: 0.0013 (0.0021)  loss_rpn_box_reg: 0.0033 (0.0034)  time: 23.3502  data: 0.0204  max mem: 7344
# Epoch: [2]  [240/297]  eta: 0:23:38  lr: 0.010000  loss: 0.0697 (0.0789)  loss_classifier: 0.0197 (0.0266)  loss_box_reg: 0.0402 (0.0469)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 22.9083  data: 0.0203  max mem: 7344
# Epoch: [2]  [250/297]  eta: 0:19:25  lr: 0.010000  loss: 0.0710 (0.0793)  loss_classifier: 0.0231 (0.0267)  loss_box_reg: 0.0412 (0.0470)  loss_objectness: 0.0024 (0.0021)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 22.6500  data: 0.0192  max mem: 7344
# Epoch: [2]  [260/297]  eta: 0:15:15  lr: 0.010000  loss: 0.0736 (0.0794)  loss_classifier: 0.0266 (0.0268)  loss_box_reg: 0.0466 (0.0471)  loss_objectness: 0.0024 (0.0021)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 23.1694  data: 0.0192  max mem: 7344
# Epoch: [2]  [270/297]  eta: 0:11:07  lr: 0.010000  loss: 0.0762 (0.0798)  loss_classifier: 0.0266 (0.0269)  loss_box_reg: 0.0459 (0.0473)  loss_objectness: 0.0020 (0.0021)  loss_rpn_box_reg: 0.0030 (0.0034)  time: 23.8475  data: 0.0186  max mem: 7344
# Epoch: [2]  [280/297]  eta: 0:07:00  lr: 0.010000  loss: 0.0841 (0.0802)  loss_classifier: 0.0275 (0.0271)  loss_box_reg: 0.0497 (0.0476)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 24.1677  data: 0.0190  max mem: 7344
# Epoch: [2]  [290/297]  eta: 0:02:52  lr: 0.010000  loss: 0.0860 (0.0803)  loss_classifier: 0.0275 (0.0271)  loss_box_reg: 0.0513 (0.0476)  loss_objectness: 0.0018 (0.0021)  loss_rpn_box_reg: 0.0033 (0.0034)  time: 23.8739  data: 0.0191  max mem: 7344
# Epoch: [2]  [296/297]  eta: 0:00:24  lr: 0.010000  loss: 0.0836 (0.0802)  loss_classifier: 0.0261 (0.0271)  loss_box_reg: 0.0497 (0.0476)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0032 (0.0034)  time: 23.5699  data: 0.0197  max mem: 7344
# Epoch: [2] Total time: 2:01:59 (24.6438 s / it)
# creating index...
# index created!
# Test:  [ 0/75]  eta: 0:09:38  model_time: 7.6554 (7.6554)  evaluator_time: 0.0156 (0.0156)  time: 7.7121  data: 0.0280  max mem: 7344
# Test:  [74/75]  eta: 0:00:07  model_time: 7.8666 (7.7040)  evaluator_time: 0.0000 (0.0032)  time: 7.5210  data: 0.0171  max mem: 7344
# Test: Total time: 0:09:39 (7.7288 s / it)
# Averaged stats: model_time: 7.8666 (7.7040)  evaluator_time: 0.0000 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.914
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.673
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.742
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.696
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.699
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.786
# Epoch: [3]  [  0/297]  eta: 1:59:57  lr: 0.001000  loss: 0.0554 (0.0554)  loss_classifier: 0.0192 (0.0192)  loss_box_reg: 0.0342 (0.0342)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0015 (0.0015)  time: 24.2330  data: 0.0216  max mem: 7344
# Epoch: [3]  [ 10/297]  eta: 1:56:34  lr: 0.001000  loss: 0.0622 (0.0618)  loss_classifier: 0.0222 (0.0209)  loss_box_reg: 0.0371 (0.0367)  loss_objectness: 0.0010 (0.0016)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 24.3725  data: 0.0113  max mem: 7344
# Epoch: [3]  [ 20/297]  eta: 1:52:38  lr: 0.001000  loss: 0.0603 (0.0590)  loss_classifier: 0.0198 (0.0192)  loss_box_reg: 0.0346 (0.0356)  loss_objectness: 0.0010 (0.0015)  loss_rpn_box_reg: 0.0026 (0.0027)  time: 24.4074  data: 0.0135  max mem: 7344
# Epoch: [3]  [ 30/297]  eta: 1:48:09  lr: 0.001000  loss: 0.0574 (0.0586)  loss_classifier: 0.0170 (0.0192)  loss_box_reg: 0.0321 (0.0354)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 24.2665  data: 0.0170  max mem: 7344
# Epoch: [3]  [ 40/297]  eta: 1:43:34  lr: 0.001000  loss: 0.0523 (0.0564)  loss_classifier: 0.0162 (0.0183)  loss_box_reg: 0.0319 (0.0341)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0021 (0.0026)  time: 23.9557  data: 0.0168  max mem: 7344
# Epoch: [3]  [ 50/297]  eta: 1:38:37  lr: 0.001000  loss: 0.0523 (0.0570)  loss_classifier: 0.0162 (0.0186)  loss_box_reg: 0.0321 (0.0346)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 23.4161  data: 0.0170  max mem: 7344
# Epoch: [3]  [ 60/297]  eta: 1:34:07  lr: 0.001000  loss: 0.0530 (0.0578)  loss_classifier: 0.0163 (0.0187)  loss_box_reg: 0.0326 (0.0352)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 23.0995  data: 0.0180  max mem: 7344
# Epoch: [3]  [ 70/297]  eta: 1:29:38  lr: 0.001000  loss: 0.0516 (0.0587)  loss_classifier: 0.0176 (0.0189)  loss_box_reg: 0.0321 (0.0360)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 23.0188  data: 0.0179  max mem: 7344
# Epoch: [3]  [ 80/297]  eta: 1:25:24  lr: 0.001000  loss: 0.0515 (0.0583)  loss_classifier: 0.0169 (0.0187)  loss_box_reg: 0.0310 (0.0357)  loss_objectness: 0.0012 (0.0013)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 22.9601  data: 0.0166  max mem: 7344
# Epoch: [3]  [ 90/297]  eta: 1:21:08  lr: 0.001000  loss: 0.0470 (0.0585)  loss_classifier: 0.0165 (0.0190)  loss_box_reg: 0.0280 (0.0357)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 22.9134  data: 0.0192  max mem: 7344
# Epoch: [3]  [100/297]  eta: 1:17:09  lr: 0.001000  loss: 0.0471 (0.0589)  loss_classifier: 0.0177 (0.0191)  loss_box_reg: 0.0297 (0.0360)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 23.0378  data: 0.0222  max mem: 7344
# Epoch: [3]  [110/297]  eta: 1:12:58  lr: 0.001000  loss: 0.0471 (0.0578)  loss_classifier: 0.0148 (0.0187)  loss_box_reg: 0.0297 (0.0353)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0028 (0.0026)  time: 22.9243  data: 0.0219  max mem: 7344
# Epoch: [3]  [120/297]  eta: 1:08:56  lr: 0.001000  loss: 0.0527 (0.0579)  loss_classifier: 0.0160 (0.0187)  loss_box_reg: 0.0324 (0.0353)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 22.7162  data: 0.0212  max mem: 7344
# Epoch: [3]  [130/297]  eta: 1:04:56  lr: 0.001000  loss: 0.0573 (0.0581)  loss_classifier: 0.0181 (0.0187)  loss_box_reg: 0.0340 (0.0355)  loss_objectness: 0.0012 (0.0013)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 22.8929  data: 0.0196  max mem: 7344
# Epoch: [3]  [140/297]  eta: 1:00:59  lr: 0.001000  loss: 0.0617 (0.0584)  loss_classifier: 0.0187 (0.0188)  loss_box_reg: 0.0376 (0.0357)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 22.9283  data: 0.0188  max mem: 7344
# Epoch: [3]  [150/297]  eta: 0:57:04  lr: 0.001000  loss: 0.0567 (0.0581)  loss_classifier: 0.0184 (0.0187)  loss_box_reg: 0.0365 (0.0356)  loss_objectness: 0.0008 (0.0013)  loss_rpn_box_reg: 0.0020 (0.0026)  time: 23.0496  data: 0.0192  max mem: 7344
# Epoch: [3]  [160/297]  eta: 0:53:10  lr: 0.001000  loss: 0.0500 (0.0576)  loss_classifier: 0.0158 (0.0185)  loss_box_reg: 0.0283 (0.0352)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 23.1531  data: 0.0204  max mem: 7344
# Epoch: [3]  [170/297]  eta: 0:49:15  lr: 0.001000  loss: 0.0453 (0.0578)  loss_classifier: 0.0155 (0.0185)  loss_box_reg: 0.0274 (0.0354)  loss_objectness: 0.0010 (0.0012)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 23.0754  data: 0.0210  max mem: 7344
# Epoch: [3]  [180/297]  eta: 0:45:21  lr: 0.001000  loss: 0.0492 (0.0573)  loss_classifier: 0.0177 (0.0184)  loss_box_reg: 0.0284 (0.0350)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 23.0167  data: 0.0193  max mem: 7344
# Epoch: [3]  [190/297]  eta: 0:41:28  lr: 0.001000  loss: 0.0445 (0.0577)  loss_classifier: 0.0143 (0.0185)  loss_box_reg: 0.0278 (0.0353)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 23.1184  data: 0.0182  max mem: 7344
# Epoch: [3]  [200/297]  eta: 0:37:34  lr: 0.001000  loss: 0.0506 (0.0576)  loss_classifier: 0.0155 (0.0186)  loss_box_reg: 0.0308 (0.0352)  loss_objectness: 0.0008 (0.0013)  loss_rpn_box_reg: 0.0021 (0.0026)  time: 23.0790  data: 0.0194  max mem: 7344
# Epoch: [3]  [210/297]  eta: 0:33:40  lr: 0.001000  loss: 0.0519 (0.0576)  loss_classifier: 0.0172 (0.0186)  loss_box_reg: 0.0314 (0.0351)  loss_objectness: 0.0009 (0.0013)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 22.9331  data: 0.0207  max mem: 7344
# Epoch: [3]  [220/297]  eta: 0:29:46  lr: 0.001000  loss: 0.0487 (0.0570)  loss_classifier: 0.0170 (0.0185)  loss_box_reg: 0.0285 (0.0347)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 22.7750  data: 0.0213  max mem: 7344
# Epoch: [3]  [230/297]  eta: 0:25:53  lr: 0.001000  loss: 0.0511 (0.0573)  loss_classifier: 0.0158 (0.0185)  loss_box_reg: 0.0291 (0.0349)  loss_objectness: 0.0008 (0.0012)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 22.7420  data: 0.0206  max mem: 7344
# Epoch: [3]  [240/297]  eta: 0:22:00  lr: 0.001000  loss: 0.0551 (0.0575)  loss_classifier: 0.0165 (0.0186)  loss_box_reg: 0.0358 (0.0351)  loss_objectness: 0.0008 (0.0012)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 22.9224  data: 0.0172  max mem: 7344
# Epoch: [3]  [250/297]  eta: 0:18:11  lr: 0.001000  loss: 0.0577 (0.0575)  loss_classifier: 0.0188 (0.0186)  loss_box_reg: 0.0354 (0.0350)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 23.7135  data: 0.0159  max mem: 7344
# Epoch: [3]  [260/297]  eta: 0:14:21  lr: 0.001000  loss: 0.0518 (0.0577)  loss_classifier: 0.0166 (0.0186)  loss_box_reg: 0.0331 (0.0352)  loss_objectness: 0.0011 (0.0013)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 24.5150  data: 0.0155  max mem: 7344
# Epoch: [3]  [270/297]  eta: 0:10:29  lr: 0.001000  loss: 0.0518 (0.0579)  loss_classifier: 0.0165 (0.0186)  loss_box_reg: 0.0316 (0.0354)  loss_objectness: 0.0008 (0.0013)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 24.5747  data: 0.0148  max mem: 7344
# Epoch: [3]  [280/297]  eta: 0:06:37  lr: 0.001000  loss: 0.0496 (0.0578)  loss_classifier: 0.0174 (0.0186)  loss_box_reg: 0.0314 (0.0353)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 24.4558  data: 0.0167  max mem: 7344
# Epoch: [3]  [290/297]  eta: 0:02:43  lr: 0.001000  loss: 0.0526 (0.0578)  loss_classifier: 0.0186 (0.0186)  loss_box_reg: 0.0305 (0.0354)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 24.4673  data: 0.0255  max mem: 7344
# Epoch: [3]  [296/297]  eta: 0:00:23  lr: 0.001000  loss: 0.0611 (0.0579)  loss_classifier: 0.0202 (0.0187)  loss_box_reg: 0.0365 (0.0354)  loss_objectness: 0.0008 (0.0013)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 24.4197  data: 0.0250  max mem: 7344
# Epoch: [3] Total time: 1:55:56 (23.4227 s / it)
# creating index...
# index created!
# Test:  [ 0/75]  eta: 0:10:22  model_time: 8.2848 (8.2848)  evaluator_time: 0.0000 (0.0000)  time: 8.3032  data: 0.0164  max mem: 7344
# Test:  [74/75]  eta: 0:00:07  model_time: 7.8826 (7.8547)  evaluator_time: 0.0000 (0.0030)  time: 7.5319  data: 0.0157  max mem: 7344
# Test: Total time: 0:09:50 (7.8780 s / it)
# Averaged stats: model_time: 7.8826 (7.8547)  evaluator_time: 0.0000 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.657
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.911
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.698
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.709
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.709
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.808
# Epoch: [4]  [  0/297]  eta: 2:02:14  lr: 0.001000  loss: 0.0848 (0.0848)  loss_classifier: 0.0254 (0.0254)  loss_box_reg: 0.0565 (0.0565)  loss_objectness: 0.0016 (0.0016)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 24.6945  data: 0.0071  max mem: 7344
# Epoch: [4]  [ 10/297]  eta: 1:55:07  lr: 0.001000  loss: 0.0600 (0.0675)  loss_classifier: 0.0194 (0.0218)  loss_box_reg: 0.0406 (0.0422)  loss_objectness: 0.0015 (0.0013)  loss_rpn_box_reg: 0.0018 (0.0023)  time: 24.0676  data: 0.0103  max mem: 7344
# Epoch: [4]  [ 20/297]  eta: 1:52:03  lr: 0.001000  loss: 0.0562 (0.0662)  loss_classifier: 0.0180 (0.0218)  loss_box_reg: 0.0313 (0.0406)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 24.2500  data: 0.0120  max mem: 7344
# Epoch: [4]  [ 30/297]  eta: 1:47:25  lr: 0.001000  loss: 0.0482 (0.0605)  loss_classifier: 0.0163 (0.0197)  loss_box_reg: 0.0293 (0.0371)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 24.1799  data: 0.0108  max mem: 7344
# Epoch: [4]  [ 40/297]  eta: 1:43:19  lr: 0.001000  loss: 0.0458 (0.0586)  loss_classifier: 0.0139 (0.0190)  loss_box_reg: 0.0283 (0.0360)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 23.9698  data: 0.0095  max mem: 7344
# Epoch: [4]  [ 50/297]  eta: 1:39:26  lr: 0.001000  loss: 0.0487 (0.0576)  loss_classifier: 0.0152 (0.0185)  loss_box_reg: 0.0292 (0.0355)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0021 (0.0024)  time: 24.1781  data: 0.0102  max mem: 7344
# Epoch: [4]  [ 60/297]  eta: 1:35:12  lr: 0.001000  loss: 0.0485 (0.0566)  loss_classifier: 0.0152 (0.0186)  loss_box_reg: 0.0287 (0.0344)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 24.0656  data: 0.0112  max mem: 7344
# Epoch: [4]  [ 70/297]  eta: 1:31:18  lr: 0.001000  loss: 0.0475 (0.0560)  loss_classifier: 0.0149 (0.0184)  loss_box_reg: 0.0288 (0.0341)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 24.0782  data: 0.0120  max mem: 7344
# Epoch: [4]  [ 80/297]  eta: 1:26:46  lr: 0.001000  loss: 0.0476 (0.0550)  loss_classifier: 0.0161 (0.0182)  loss_box_reg: 0.0297 (0.0332)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0020 (0.0024)  time: 23.6498  data: 0.0137  max mem: 7344
# Epoch: [4]  [ 90/297]  eta: 1:24:03  lr: 0.001000  loss: 0.0485 (0.0555)  loss_classifier: 0.0169 (0.0182)  loss_box_reg: 0.0299 (0.0337)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0021 (0.0024)  time: 25.1828  data: 0.0181  max mem: 7344
# Epoch: [4]  [100/297]  eta: 1:24:58  lr: 0.001000  loss: 0.0414 (0.0546)  loss_classifier: 0.0145 (0.0179)  loss_box_reg: 0.0257 (0.0331)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 33.5234  data: 0.0181  max mem: 7344
# Epoch: [4]  [110/297]  eta: 1:25:16  lr: 0.001000  loss: 0.0403 (0.0533)  loss_classifier: 0.0128 (0.0174)  loss_box_reg: 0.0243 (0.0324)  loss_objectness: 0.0006 (0.0011)  loss_rpn_box_reg: 0.0020 (0.0024)  time: 41.0094  data: 0.0160  max mem: 7344
# Epoch: [4]  [120/297]  eta: 1:24:15  lr: 0.001000  loss: 0.0413 (0.0539)  loss_classifier: 0.0141 (0.0175)  loss_box_reg: 0.0262 (0.0328)  loss_objectness: 0.0010 (0.0012)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 42.1194  data: 0.0156  max mem: 7344
# Epoch: [4]  [130/297]  eta: 1:22:23  lr: 0.001000  loss: 0.0494 (0.0533)  loss_classifier: 0.0157 (0.0173)  loss_box_reg: 0.0293 (0.0324)  loss_objectness: 0.0010 (0.0012)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 42.0440  data: 0.0156  max mem: 7344
# Epoch: [4]  [140/297]  eta: 1:19:35  lr: 0.001000  loss: 0.0434 (0.0526)  loss_classifier: 0.0129 (0.0171)  loss_box_reg: 0.0265 (0.0319)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 41.6470  data: 0.0178  max mem: 7344
# Epoch: [4]  [150/297]  eta: 1:16:13  lr: 0.001000  loss: 0.0459 (0.0531)  loss_classifier: 0.0147 (0.0171)  loss_box_reg: 0.0265 (0.0324)  loss_objectness: 0.0011 (0.0012)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 40.9801  data: 0.0197  max mem: 7344
# Epoch: [4]  [160/297]  eta: 1:12:40  lr: 0.001000  loss: 0.0441 (0.0531)  loss_classifier: 0.0140 (0.0171)  loss_box_reg: 0.0256 (0.0324)  loss_objectness: 0.0008 (0.0011)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 41.7408  data: 0.0190  max mem: 7344
# Epoch: [4]  [170/297]  eta: 1:08:44  lr: 0.001000  loss: 0.0471 (0.0541)  loss_classifier: 0.0175 (0.0174)  loss_box_reg: 0.0308 (0.0330)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 42.7799  data: 0.0183  max mem: 7344
# Epoch: [4]  [180/297]  eta: 1:04:23  lr: 0.001000  loss: 0.0564 (0.0539)  loss_classifier: 0.0175 (0.0174)  loss_box_reg: 0.0308 (0.0329)  loss_objectness: 0.0010 (0.0011)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 42.6478  data: 0.0193  max mem: 7344
# Epoch: [4]  [190/297]  eta: 0:59:39  lr: 0.001000  loss: 0.0457 (0.0536)  loss_classifier: 0.0149 (0.0173)  loss_box_reg: 0.0282 (0.0328)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 41.8427  data: 0.0191  max mem: 7344
# Epoch: [4]  [200/297]  eta: 0:54:44  lr: 0.001000  loss: 0.0470 (0.0534)  loss_classifier: 0.0148 (0.0172)  loss_box_reg: 0.0286 (0.0326)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 41.4405  data: 0.0188  max mem: 7344
# Epoch: [4]  [210/297]  eta: 0:49:40  lr: 0.001000  loss: 0.0476 (0.0535)  loss_classifier: 0.0145 (0.0172)  loss_box_reg: 0.0305 (0.0328)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 41.9092  data: 0.0185  max mem: 7344
# Epoch: [4]  [220/297]  eta: 0:44:24  lr: 0.001000  loss: 0.0470 (0.0531)  loss_classifier: 0.0154 (0.0170)  loss_box_reg: 0.0319 (0.0325)  loss_objectness: 0.0006 (0.0011)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 42.1246  data: 0.0197  max mem: 7344
# Epoch: [4]  [230/297]  eta: 0:39:01  lr: 0.001000  loss: 0.0443 (0.0529)  loss_classifier: 0.0145 (0.0170)  loss_box_reg: 0.0258 (0.0324)  loss_objectness: 0.0008 (0.0011)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 42.1493  data: 0.0195  max mem: 7344
# Epoch: [4]  [240/297]  eta: 0:33:25  lr: 0.001000  loss: 0.0443 (0.0529)  loss_classifier: 0.0141 (0.0169)  loss_box_reg: 0.0272 (0.0324)  loss_objectness: 0.0008 (0.0011)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 41.6326  data: 0.0181  max mem: 7344
# Epoch: [4]  [250/297]  eta: 0:27:45  lr: 0.001000  loss: 0.0460 (0.0530)  loss_classifier: 0.0141 (0.0169)  loss_box_reg: 0.0293 (0.0325)  loss_objectness: 0.0009 (0.0011)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 41.1412  data: 0.0176  max mem: 7344
# Epoch: [4]  [260/297]  eta: 0:22:00  lr: 0.001000  loss: 0.0498 (0.0527)  loss_classifier: 0.0144 (0.0169)  loss_box_reg: 0.0305 (0.0323)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 41.7038  data: 0.0171  max mem: 7344
# Epoch: [4]  [270/297]  eta: 0:16:09  lr: 0.001000  loss: 0.0473 (0.0526)  loss_classifier: 0.0153 (0.0168)  loss_box_reg: 0.0272 (0.0322)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0020 (0.0025)  time: 41.9547  data: 0.0192  max mem: 7344
# Epoch: [4]  [280/297]  eta: 0:10:13  lr: 0.001000  loss: 0.0474 (0.0530)  loss_classifier: 0.0162 (0.0169)  loss_box_reg: 0.0274 (0.0325)  loss_objectness: 0.0009 (0.0011)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 41.3966  data: 0.0197  max mem: 7344
# Epoch: [4]  [290/297]  eta: 0:04:13  lr: 0.001000  loss: 0.0534 (0.0532)  loss_classifier: 0.0183 (0.0170)  loss_box_reg: 0.0314 (0.0327)  loss_objectness: 0.0010 (0.0011)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 40.9238  data: 0.0201  max mem: 7344
# Epoch: [4]  [296/297]  eta: 0:00:36  lr: 0.001000  loss: 0.0532 (0.0532)  loss_classifier: 0.0187 (0.0170)  loss_box_reg: 0.0314 (0.0326)  loss_objectness: 0.0008 (0.0011)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 41.1694  data: 0.0204  max mem: 7344
# Epoch: [4] Total time: 3:00:02 (36.3713 s / it)
# creating index...
# index created!
# Test:  [ 0/75]  eta: 0:18:04  model_time: 14.4134 (14.4134)  evaluator_time: 0.0026 (0.0026)  time: 14.4535  data: 0.0200  max mem: 7344
# Test:  [74/75]  eta: 0:00:14  model_time: 14.1673 (14.0240)  evaluator_time: 0.0005 (0.0027)  time: 13.5196  data: 0.0165  max mem: 7344
# Test: Total time: 0:17:33 (14.0495 s / it)
# Averaged stats: model_time: 14.1673 (14.0240)  evaluator_time: 0.0005 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.654
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.911
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.695
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.325
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.436
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.806

# %%
path_model =  "Model/faster_rcnn_higher_lr.onnx"
if not os.path.exists("Model"):
    os.makedirs("Model")

# %%
input = torch.randn(1, 3, 150, 150)
print(input.shape)
torch.onnx.export(model, input.cuda(), path_model, export_params=True, opset_version = 17, input_names = ['image'], output_names = ['boxes', 'labels', 'scores'])
# Out:
# torch.Size([1, 3, 150, 150])
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\functional.py:3982: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   (torch.floor((input.size(i + 2).float() * torch.tensor(scale_factors[i], dtype=torch.float32)).float()))
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\ops\boxes.py:157: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_x = torch.min(boxes_x, torch.tensor(width, dtype=boxes.dtype, device=boxes.device))
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\ops\boxes.py:159: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_y = torch.min(boxes_y, torch.tensor(height, dtype=boxes.dtype, device=boxes.device))
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:1493: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert condition, message
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\detection\transform.py:308: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(s, dtype=torch.float32, device=boxes.device)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\detection\transform.py:309: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   / torch.tensor(s_orig, dtype=torch.float32, device=boxes.device)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\onnx\symbolic_opset9.py:5859: UserWarning: Exporting aten::index operator of advanced indexing in opset 17 is achieved by combination of multiple ONNX operators, including Reshape, Transpose, Concat, and Gather. If indices include negative values, the exported graph will produce incorrect results.
#   warnings.warn(
