# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import xml.etree.ElementTree as ET
import os

HOME = os.path.abspath(os.sep)
dataset_folder = os.getcwd() + "/Dataset/Images"

# %%
import os
import json
import torch
from PIL import Image
from torch.utils.data import Dataset

class GunDataset(Dataset):
    def __init__(self, root_dir, annotations_file, transforms=None, custom_transforms=None):
        """
        Args:
            root_dir (str): Directory contenente le immagini.
            annotations_file (str): Percorso al file _annotations.coco.json.
            transform (callable, optional): Trasformazioni da applicare alle immagini.
        """
        # Carica annotazioni COCO
        with open(annotations_file, 'r') as f:
            coco_data = json.load(f)
            
        self.root_dir = root_dir
        self.transforms = transforms
        self.custom_transforms = custom_transforms
        self.images = coco_data['images']
        self.annotations = coco_data['annotations']
        self.classes = ['gun']

        # Organizza annotazioni per immagine
        self.img_to_anns = {img['id']: [] for img in self.images}
        for ann in self.annotations:
            self.img_to_anns[ann['image_id']].append(ann)

    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        # Recupera l'immagine
        img_info = self.images[idx]
        img_id = img_info['id']
        img_path = f"{self.root_dir}/{img_info['file_name']}"
        image = Image.open(img_path).convert("RGB")

        # Recupera le annotazioni per questa immagine
        annotations = self.img_to_anns[img_id]
        boxes = []
        labels = []
        iscrowd = []
        areas = []  # Lista per memorizzare l'area di ogni bounding box

        for ann in annotations:
            # Estrai il bounding box (x_min, y_min, width, height)
            bbox = ann['bbox']
            x_min, y_min, width, height = bbox
            x_max = x_min + width
            y_max = y_min + height
            boxes.append([x_min, y_min, x_max, y_max])
            # Calcola l'area del bounding box
            area = width * height
            areas.append(area)

            # Aggiungi l'etichetta della categoria (ad esempio "pistola")
            label = ann['category_id']
            labels.append(label)

            # Indica se l'oggetto è occluso
            iscrowd.append(ann.get('iscrowd', 0))
        
        if self.transforms and self.custom_transforms is None:
            image = self.transforms(image)
        # Applica le trasformazioni se presenti
        if self.custom_transforms:
            # Passa il dizionario con 'image', 'bboxes', 'category_ids'
            transformed = self.custom_transforms(image=np.array(image), bboxes=boxes, category_ids=labels)
            image = transformed['image']
            boxes = transformed['bboxes']
            labels = transformed['category_ids']    
                    
        # Converti le annotazioni in tensori
        boxes = torch.tensor(boxes, dtype=torch.float32)
        labels = torch.tensor(labels, dtype=torch.int64)
        iscrowd = torch.tensor(iscrowd, dtype=torch.int64)
        areas = torch.tensor(areas, dtype=torch.float32)
        
        # Crea il dizionario delle annotazioni
        target = {
            'image_id': img_id,
            'boxes': boxes,
            'labels': labels,
            'iscrowd': iscrowd,
            'area': areas  # Aggiungi l'area nel dizionario
        }
        
        return image, target

# %%
import torchvision.transforms as T
from torch.utils.data import DataLoader, random_split

transforms = T.Compose([T.ToTensor()])

# load dataset
dataset = GunDataset(dataset_folder, dataset_folder + "/_annotations.coco.json", transforms=transforms)

# define splits
train_size = int(0.8*len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Definisci le trasformazioni
training_transform = A.Compose([
    A.HorizontalFlip(p=0.5),  # Flip orizzontale casuale
    A.VerticalFlip(p=0.5),  # Flip verticale casuale
    A.Rotate(limit=10, p=0.5),  # Ruota l'immagine
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5), # Regola luminosità e contrasto
    A.GaussNoise(std_range=(0.025,0.05), p=0.5),  # Aggiungi rumore gaussiano
    A.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0,1.0,1.0]),  # Normalizza l'immagine
    ToTensorV2()  # Converti l'immagine e le annotazioni in tensori PyTorch
], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['category_ids'], clip=True))


train_dataset.dataset.custom_transforms = training_transform

# %%
num_workers = 2
#num_workers
if os.name == 'nt':
    num_workers = 0

# data loaders
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=num_workers, collate_fn=lambda x: tuple(zip(*x)), pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, num_workers=num_workers, collate_fn=lambda x: tuple(zip(*x)))

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FasterRCNN_ResNet50_FPN_Weights
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
num_classes = 2
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 3, gamma = 0.1)

# %%
from engine import train_one_epoch, evaluate
num_epochs = 5
for epoch in range(5):
    train_loss = train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)
    lr_scheduler.step()
    val_loss = evaluate(model, val_loader, device)
# Out:
# Epoch: [0]  [  0/297]  eta: 2:33:23  lr: 0.000022  loss: 0.8550 (0.8550)  loss_classifier: 0.6763 (0.6763)  loss_box_reg: 0.1379 (0.1379)  loss_objectness: 0.0335 (0.0335)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 30.9891  data: 0.1079  max mem: 11524
# Epoch: [0]  [ 10/297]  eta: 1:58:54  lr: 0.000191  loss: 0.7639 (0.6978)  loss_classifier: 0.5756 (0.5315)  loss_box_reg: 0.1307 (0.1409)  loss_objectness: 0.0119 (0.0148)  loss_rpn_box_reg: 0.0098 (0.0106)  time: 24.8580  data: 0.0801  max mem: 11524
# Epoch: [0]  [ 20/297]  eta: 1:55:03  lr: 0.000359  loss: 0.3888 (0.5158)  loss_classifier: 0.2253 (0.3540)  loss_box_reg: 0.1307 (0.1336)  loss_objectness: 0.0152 (0.0182)  loss_rpn_box_reg: 0.0091 (0.0099)  time: 24.6206  data: 0.0788  max mem: 11524
# Epoch: [0]  [ 30/297]  eta: 1:49:22  lr: 0.000528  loss: 0.3005 (0.4449)  loss_classifier: 0.1446 (0.2879)  loss_box_reg: 0.1163 (0.1310)  loss_objectness: 0.0146 (0.0164)  loss_rpn_box_reg: 0.0090 (0.0097)  time: 24.4256  data: 0.0801  max mem: 11524
# Epoch: [0]  [ 40/297]  eta: 1:44:58  lr: 0.000697  loss: 0.2705 (0.4084)  loss_classifier: 0.1322 (0.2517)  loss_box_reg: 0.1157 (0.1298)  loss_objectness: 0.0130 (0.0174)  loss_rpn_box_reg: 0.0089 (0.0096)  time: 24.0715  data: 0.0763  max mem: 11524
# Epoch: [0]  [ 50/297]  eta: 1:39:21  lr: 0.000866  loss: 0.2671 (0.3834)  loss_classifier: 0.1228 (0.2236)  loss_box_reg: 0.1204 (0.1338)  loss_objectness: 0.0129 (0.0166)  loss_rpn_box_reg: 0.0091 (0.0094)  time: 23.4465  data: 0.0782  max mem: 11524
  loss_rpn_box_reg: 0.0039 (0.0039)  time: 26.4795  data: 0.0719  max mem: 11524
# Epoch: [3]  [130/297]  eta: 1:14:45  lr: 0.000500  loss: 0.0914 (0.1056)  loss_classifier: 0.0304 (0.0372)  loss_box_reg: 0.0556 (0.0600)  loss_objectness: 0.0033 (0.0045)  loss_rpn_box_reg: 0.0037 (0.0040)  time: 26.1524  data: 0.0683  max mem: 11524
# Epoch: [3]  [140/297]  eta: 1:10:23  lr: 0.000500  loss: 0.0884 (0.1055)  loss_classifier: 0.0316 (0.0371)  loss_box_reg: 0.0556 (0.0598)  loss_objectness: 0.0020 (0.0045)  loss_rpn_box_reg: 0.0037 (0.0040)  time: 26.6657  data: 0.0715  max mem: 11524
# Epoch: [3]  [150/297]  eta: 1:06:17  lr: 0.000500  loss: 0.1055 (0.1068)  loss_classifier: 0.0362 (0.0377)  loss_box_reg: 0.0590 (0.0605)  loss_objectness: 0.0022 (0.0046)  loss_rpn_box_reg: 0.0045 (0.0041)  time: 28.3723  data: 0.0784  max mem: 11524
# Epoch: [3]  [160/297]  eta: 1:02:05  lr: 0.000500  loss: 0.0987 (0.1058)  loss_classifier: 0.0362 (0.0374)  loss_box_reg: 0.0543 (0.0599)  loss_objectness: 0.0024 (0.0045)  loss_rpn_box_reg: 0.0039 (0.0041)  time: 29.2172  data: 0.0799  max mem: 11524
# Epoch: [3]  [170/297]  eta: 0:57:26  lr: 0.000500  loss: 0.0887 (0.1052)  loss_classifier: 0.0309 (0.0371)  loss_box_reg: 0.0487 (0.0596)  loss_objectness: 0.0025 (0.0044)  loss_rpn_box_reg: 0.0038 (0.0041)  time: 27.7544  data: 0.0797  max mem: 11524
# Epoch: [3]  [180/297]  eta: 0:52:43  lr: 0.000500  loss: 0.0948 (0.1053)  loss_classifier: 0.0336 (0.0372)  loss_box_reg: 0.0534 (0.0596)  loss_objectness: 0.0029 (0.0043)  loss_rpn_box_reg: 0.0040 (0.0041)  time: 25.8016  data: 0.0816  max mem: 11524
# Epoch: [3]  [190/297]  eta: 0:47:59  lr: 0.000500  loss: 0.0948 (0.1044)  loss_classifier: 0.0336 (0.0369)  loss_box_reg: 0.0520 (0.0592)  loss_objectness: 0.0026 (0.0042)  loss_rpn_box_reg: 0.0036 (0.0041)  time: 24.9846  data: 0.0830  max mem: 11524
# Epoch: [3]  [200/297]  eta: 0:43:41  lr: 0.000500  loss: 0.0847 (0.1033)  loss_classifier: 0.0287 (0.0365)  loss_box_reg: 0.0465 (0.0586)  loss_objectness: 0.0020 (0.0042)  loss_rpn_box_reg: 0.0036 (0.0041)  time: 26.9096  data: 0.0827  max mem: 11524
# Epoch: [3] Total time: 2:17:02 (27.6846 s / it)
# creating index...
# index created!
# Test:  [ 0/75]  eta: 0:09:51  model_time: 7.8134 (7.8134)  evaluator_time: 0.0040 (0.0040)  time: 7.8878  data: 0.0558  max mem: 11524
# Test:  [74/75]  eta: 0:00:07  model_time: 7.4311 (7.2952)  evaluator_time: 0.0031 (0.0040)  time: 7.3183  data: 0.0697  max mem: 11524
# Test: Total time: 0:09:13 (7.3765 s / it)
# Averaged stats: model_time: 7.4311 (7.2952)  evaluator_time: 0.0031 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.574
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.391
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.445
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
# Epoch: [4]  [  0/297]  eta: 2:17:47  lr: 0.000500  loss: 0.0860 (0.0860)  loss_classifier: 0.0229 (0.0229)  loss_box_reg: 0.0586 (0.0586)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 27.8379  data: 0.0821  max mem: 11524
# Epoch: [4]  [ 10/297]  eta: 2:02:29  lr: 0.000500  loss: 0.0791 (0.0789)  loss_classifier: 0.0229 (0.0248)  loss_box_reg: 0.0461 (0.0481)  loss_objectness: 0.0020 (0.0027)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 25.6084  data: 0.0703  max mem: 11524
# Epoch: [4]  [ 20/297]  eta: 1:56:45  lr: 0.000500  loss: 0.0748 (0.0861)  loss_classifier: 0.0233 (0.0279)  loss_box_reg: 0.0461 (0.0518)  loss_objectness: 0.0022 (0.0027)  loss_rpn_box_reg: 0.0031 (0.0037)  time: 25.1617  data: 0.0762  max mem: 11524
# Epoch: [4]  [ 30/297]  eta: 1:51:49  lr: 0.000500  loss: 0.0763 (0.0850)  loss_classifier: 0.0241 (0.0278)  loss_box_reg: 0.0454 (0.0510)  loss_objectness: 0.0016 (0.0024)  loss_rpn_box_reg: 0.0035 (0.0037)  time: 24.8649  data: 0.0764  max mem: 11524
# Epoch: [4]  [ 40/297]  eta: 1:47:05  lr: 0.000500  loss: 0.0705 (0.0821)  loss_classifier: 0.0242 (0.0268)  loss_box_reg: 0.0426 (0.0492)  loss_objectness: 0.0015 (0.0022)  loss_rpn_box_reg: 0.0035 (0.0038)  time: 24.7040  data: 0.0680  max mem: 11524
# Epoch: [4]  [ 50/297]  eta: 1:43:59  lr: 0.000500  loss: 0.0817 (0.0833)  loss_classifier: 0.0272 (0.0281)  loss_box_reg: 0.0460 (0.0493)  loss_objectness: 0.0013 (0.0022)  loss_rpn_box_reg: 0.0035 (0.0038)  time: 25.4660  data: 0.0701  max mem: 11524
# Epoch: [4]  [ 60/297]  eta: 1:40:31  lr: 0.000500  loss: 0.0847 (0.0844)  loss_classifier: 0.0313 (0.0286)  loss_box_reg: 0.0505 (0.0498)  loss_objectness: 0.0016 (0.0024)  loss_rpn_box_reg: 0.0035 (0.0037)  time: 26.3673  data: 0.0737  max mem: 11524
# Epoch: [4]  [ 70/297]  eta: 1:36:39  lr: 0.000500  loss: 0.0902 (0.0882)  loss_classifier: 0.0332 (0.0304)  loss_box_reg: 0.0471 (0.0511)  loss_objectness: 0.0024 (0.0026)  loss_rpn_box_reg: 0.0035 (0.0040)  time: 26.2759  data: 0.0751  max mem: 11524
# Epoch: [4]  [ 80/297]  eta: 1:32:53  lr: 0.000500  loss: 0.0934 (0.0891)  loss_classifier: 0.0342 (0.0310)  loss_box_reg: 0.0508 (0.0514)  loss_objectness: 0.0025 (0.0027)  loss_rpn_box_reg: 0.0038 (0.0040)  time: 26.3881  data: 0.0744  max mem: 11524
# Epoch: [4]  [ 90/297]  eta: 1:28:52  lr: 0.000500  loss: 0.0866 (0.0883)  loss_classifier: 0.0303 (0.0305)  loss_box_reg: 0.0485 (0.0512)  loss_objectness: 0.0023 (0.0027)  loss_rpn_box_reg: 0.0039 (0.0040)  time: 26.5256  data: 0.0736  max mem: 11524
# Epoch: [4]  [100/297]  eta: 1:24:54  lr: 0.000500  loss: 0.0767 (0.0876)  loss_classifier: 0.0247 (0.0300)  loss_box_reg: 0.0471 (0.0510)  loss_objectness: 0.0018 (0.0026)  loss_rpn_box_reg: 0.0037 (0.0040)  time: 26.5940  data: 0.0730  max mem: 11524
# Epoch: [4]  [110/297]  eta: 1:20:51  lr: 0.000500  loss: 0.0867 (0.0894)  loss_classifier: 0.0305 (0.0305)  loss_box_reg: 0.0508 (0.0522)  loss_objectness: 0.0016 (0.0026)  loss_rpn_box_reg: 0.0037 (0.0040)  time: 26.7707  data: 0.0725  max mem: 11524
# Epoch: [4]  [120/297]  eta: 1:16:39  lr: 0.000500  loss: 0.0984 (0.0908)  loss_classifier: 0.0358 (0.0312)  loss_box_reg: 0.0565 (0.0527)  loss_objectness: 0.0032 (0.0029)  loss_rpn_box_reg: 0.0039 (0.0040)  time: 26.6181  data: 0.0722  max mem: 11524
# Epoch: [4]  [130/297]  eta: 1:12:25  lr: 0.000500  loss: 0.1017 (0.0919)  loss_classifier: 0.0363 (0.0317)  loss_box_reg: 0.0544 (0.0530)  loss_objectness: 0.0037 (0.0030)  loss_rpn_box_reg: 0.0039 (0.0042)  time: 26.4430  data: 0.0753  max mem: 11524
# Epoch: [4]  [140/297]  eta: 1:08:13  lr: 0.000500  loss: 0.0929 (0.0913)  loss_classifier: 0.0352 (0.0315)  loss_box_reg: 0.0539 (0.0527)  loss_objectness: 0.0036 (0.0030)  loss_rpn_box_reg: 0.0034 (0.0041)  time: 26.5906  data: 0.0790  max mem: 11524
# Epoch: [4]  [150/297]  eta: 1:03:55  lr: 0.000500  loss: 0.0857 (0.0921)  loss_classifier: 0.0286 (0.0318)  loss_box_reg: 0.0514 (0.0532)  loss_objectness: 0.0027 (0.0031)  loss_rpn_box_reg: 0.0032 (0.0041)  time: 26.5583  data: 0.0752  max mem: 11524
# Epoch: [4]  [160/297]  eta: 0:59:35  lr: 0.000500  loss: 0.0971 (0.0931)  loss_classifier: 0.0320 (0.0324)  loss_box_reg: 0.0535 (0.0534)  loss_objectness: 0.0027 (0.0032)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 26.3056  data: 0.0769  max mem: 11524
# Epoch: [4]  [170/297]  eta: 0:55:18  lr: 0.000500  loss: 0.1041 (0.0949)  loss_classifier: 0.0417 (0.0331)  loss_box_reg: 0.0557 (0.0546)  loss_objectness: 0.0030 (0.0032)  loss_rpn_box_reg: 0.0033 (0.0041)  time: 26.4046  data: 0.0822  max mem: 11524
# Epoch: [4]  [180/297]  eta: 0:51:00  lr: 0.000500  loss: 0.0990 (0.0950)  loss_classifier: 0.0355 (0.0330)  loss_box_reg: 0.0575 (0.0546)  loss_objectness: 0.0030 (0.0032)  loss_rpn_box_reg: 0.0034 (0.0041)  time: 26.6406  data: 0.0804  max mem: 11524
# Epoch: [4]  [190/297]  eta: 0:46:40  lr: 0.000500  loss: 0.0811 (0.0950)  loss_classifier: 0.0281 (0.0331)  loss_box_reg: 0.0478 (0.0546)  loss_objectness: 0.0024 (0.0033)  loss_rpn_box_reg: 0.0040 (0.0041)  time: 26.5648  data: 0.0739  max mem: 11524
# Epoch: [4]  [200/297]  eta: 0:42:22  lr: 0.000500  loss: 0.0892 (0.0959)  loss_classifier: 0.0323 (0.0335)  loss_box_reg: 0.0523 (0.0551)  loss_objectness: 0.0025 (0.0033)  loss_rpn_box_reg: 0.0037 (0.0041)  time: 26.6290  data: 0.0748  max mem: 11524
# Epoch: [4]  [210/297]  eta: 0:38:00  lr: 0.000500  loss: 0.0948 (0.0962)  loss_classifier: 0.0346 (0.0336)  loss_box_reg: 0.0578 (0.0553)  loss_objectness: 0.0030 (0.0033)  loss_rpn_box_reg: 0.0031 (0.0040)  time: 26.6356  data: 0.0789  max mem: 11524
# Epoch: [4]  [220/297]  eta: 0:33:39  lr: 0.000500  loss: 0.0939 (0.0965)  loss_classifier: 0.0322 (0.0337)  loss_box_reg: 0.0570 (0.0554)  loss_objectness: 0.0029 (0.0034)  loss_rpn_box_reg: 0.0031 (0.0040)  time: 26.3756  data: 0.0802  max mem: 11524
# Epoch: [4]  [230/297]  eta: 0:29:18  lr: 0.000500  loss: 0.1041 (0.0971)  loss_classifier: 0.0347 (0.0339)  loss_box_reg: 0.0570 (0.0558)  loss_objectness: 0.0029 (0.0034)  loss_rpn_box_reg: 0.0035 (0.0040)  time: 26.4914  data: 0.0803  max mem: 11524
# Epoch: [4]  [240/297]  eta: 0:24:56  lr: 0.000500  loss: 0.0869 (0.0966)  loss_classifier: 0.0283 (0.0336)  loss_box_reg: 0.0539 (0.0557)  loss_objectness: 0.0027 (0.0034)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 26.6164  data: 0.0832  max mem: 11524
# Epoch: [4]  [250/297]  eta: 0:20:34  lr: 0.000500  loss: 0.0740 (0.0959)  loss_classifier: 0.0220 (0.0334)  loss_box_reg: 0.0455 (0.0552)  loss_objectness: 0.0013 (0.0034)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 26.6407  data: 0.0853  max mem: 11524
# Epoch: [4]  [260/297]  eta: 0:16:13  lr: 0.000500  loss: 0.0923 (0.0973)  loss_classifier: 0.0306 (0.0339)  loss_box_reg: 0.0531 (0.0560)  loss_objectness: 0.0016 (0.0034)  loss_rpn_box_reg: 0.0035 (0.0040)  time: 26.8739  data: 0.0775  max mem: 11524
# Epoch: [4]  [270/297]  eta: 0:11:50  lr: 0.000500  loss: 0.1054 (0.0979)  loss_classifier: 0.0415 (0.0342)  loss_box_reg: 0.0548 (0.0562)  loss_objectness: 0.0028 (0.0035)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 26.7856  data: 0.0749  max mem: 11524
# Epoch: [4]  [280/297]  eta: 0:07:27  lr: 0.000500  loss: 0.1094 (0.0982)  loss_classifier: 0.0423 (0.0344)  loss_box_reg: 0.0572 (0.0563)  loss_objectness: 0.0036 (0.0035)  loss_rpn_box_reg: 0.0041 (0.0040)  time: 26.4624  data: 0.0774  max mem: 11524
# Epoch: [4]  [290/297]  eta: 0:03:04  lr: 0.000500  loss: 0.0960 (0.0987)  loss_classifier: 0.0370 (0.0346)  loss_box_reg: 0.0595 (0.0566)  loss_objectness: 0.0029 (0.0035)  loss_rpn_box_reg: 0.0032 (0.0040)  time: 26.7038  data: 0.0751  max mem: 11524
# Epoch: [4]  [296/297]  eta: 0:00:26  lr: 0.000500  loss: 0.0922 (0.0984)  loss_classifier: 0.0309 (0.0345)  loss_box_reg: 0.0567 (0.0564)  loss_objectness: 0.0024 (0.0035)  loss_rpn_box_reg: 0.0031 (0.0040)  time: 26.7440  data: 0.0749  max mem: 11524
# Epoch: [4] Total time: 2:10:23 (26.3429 s / it)
# creating index...
# index created!
# Test:  [ 0/75]  eta: 0:09:40  model_time: 7.6496 (7.6496)  evaluator_time: 0.0176 (0.0176)  time: 7.7341  data: 0.0530  max mem: 11524
# Test:  [74/75]  eta: 0:00:07  model_time: 7.3942 (7.3298)  evaluator_time: 0.0000 (0.0049)  time: 7.2399  data: 0.0668  max mem: 11524
# Test: Total time: 0:09:15 (7.4048 s / it)
# Averaged stats: model_time: 7.3942 (7.3298)  evaluator_time: 0.0000 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.533

# %%
path_model =  "Model/faster_rcnn_data_augmentation.onnx"
if not os.path.exists("Model"):
    os.makedirs("Model")

# %%
input = torch.randn(1, 3, 150, 150)
print(input.shape)
torch.onnx.export(model, input.cuda(), path_model, export_params=True, opset_version = 17, input_names = ['image'], output_names = ['boxes', 'labels', 'scores'])
# Out:
# torch.Size([1, 3, 150, 150])
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\functional.py:3982: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   (torch.floor((input.size(i + 2).float() * torch.tensor(scale_factors[i], dtype=torch.float32)).float()))
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\ops\boxes.py:157: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_x = torch.min(boxes_x, torch.tensor(width, dtype=boxes.dtype, device=boxes.device))
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\ops\boxes.py:159: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_y = torch.min(boxes_y, torch.tensor(height, dtype=boxes.dtype, device=boxes.device))
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:1493: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert condition, message
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\detection\transform.py:308: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(s, dtype=torch.float32, device=boxes.device)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\detection\transform.py:309: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   / torch.tensor(s_orig, dtype=torch.float32, device=boxes.device)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\onnx\symbolic_opset9.py:5859: UserWarning: Exporting aten::index operator of advanced indexing in opset 17 is achieved by combination of multiple ONNX operators, including Reshape, Transpose, Concat, and Gather. If indices include negative values, the exported graph will produce incorrect results.
#   warnings.warn(
